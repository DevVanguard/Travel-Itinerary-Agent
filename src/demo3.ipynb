# %%
# Travel Itinerary Agent - Complete Demo with Pakistan Cities
import sys
import os
sys.path.append('src')

print("🚀 Travel Itinerary Agent - Complete Demo with Pakistan")
print("=" * 60)

# Import all tools
from tools.destination_research import research_destination
from tools.itinerary_builder import build_daily_itinerary
from tools.budget_calculator import calculate_budget_breakdown, generate_budget_chart
from tools.weather_checker import get_seasonal_weather
from tools.map_visualizer import generate_itinerary_map

print("✅ All tools imported successfully!")
# Out:
# 🚀 Travel Itinerary Agent - Complete Demo with Pakistan
# ...
# ✅ All tools imported successfully!

# %%
# Create Mock Agent
class MockAgent:
    def __init__(self):
        self.tools = [
            research_destination,
            build_daily_itinerary,
            calculate_budget_breakdown,
            get_seasonal_weather,
            generate_itinerary_map,
            generate_budget_chart
        ]
    
    def plan_trip(self, destination, duration, budget, style="mixed", travelers=1, interests=None, month="May"):
        print(f"🚀 Planning {duration}-day {style} trip to {destination}...")
        
        # Simulate LangGraph workflow steps
        steps = [
            "🔍 Researching destination...",
            "📅 Building itinerary...", 
            "💰 Calculating budget...",
            "🌤️ Checking weather...",
            "🗺️ Generating visualizations...",
            "📝 Creating final report..."
        ]
        
        for step in steps:
            print(step)
        
        # Execute tools sequentially (simulating LangGraph)
        dest_info = research_destination(destination, interests or ["sightseeing"])
        itinerary = build_daily_itinerary(destination, duration, style, dest_info['attractions'][:4])
        budget_data = calculate_budget_breakdown(destination, duration, budget, style, travelers)
        weather_info = get_seasonal_weather(destination, month)
        itinerary_map = generate_itinerary_map(destination, itinerary, dest_info['attractions'][:3])
        budget_viz = generate_budget_chart(budget_data['budget_breakdown'])
        
        return {
            'destination': destination,
            'itinerary': itinerary,
            'budget': budget_data,
            'weather': weather_info,
            'map': itinerary_map,
            'budget_chart': budget_viz,
            'attractions': dest_info['attractions'][:5],
            'researched_destinations': dest_info
        }

print("✅ Mock Agent created successfully!")
mock_agent = MockAgent()
# Out:
# ✅ Mock Agent created successfully!

# %%
#test pakistani studies

# Test Pakistan Cities
print("🇵🇰 TESTING PAKISTAN CITIES")
print("=" * 40)

pakistan_cities = ["Islamabad", "Karachi", "Lahore", "Hunza", "Swat"]

print("Quick test of all Pakistan cities:\n")

for city in pakistan_cities:
    print(f"🏙️ Testing {city}...")
    try:
        result = mock_agent.plan_trip(
            destination=city,
            duration=3,
            budget=500,
            style="cultural",
            travelers=2,
            month="April"
        )
        print(f"   ✅ SUCCESS: {len(result['attractions'])} attractions")
        print(f"   💰 ${result['budget']['total_budget']} | 🌤️ {result['weather']['temperature']}")
        print()
    except Exception as e:
        print(f"   ❌ ERROR: {e}")
        print()
# Out:
# 🇵🇰 TESTING PAKISTAN CITIES
# ...
# Quick test of all Pakistan cities:
#
# 🏙️ Testing Islamabad...
# 🚀 Planning 3-day cultural trip to Islamabad...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
# /workspaces/Travel-Itinerary-Agent/src/tools/map_visualizer.py:102: UserWarning: Glyph 127749 (\N{SUNRISE}) missing from font(s) DejaVu Sans.
#   plt.savefig(buf, format='png', bbox_inches='tight', dpi=120, facecolor=fig.get_facecolor())
# /workspaces/Travel-Itinerary-Agent/src/tools/map_visualizer.py:102: UserWarning: Glyph 127751 (\N{SUNSET OVER BUILDINGS}) missing from font(s) DejaVu Sans.
#   plt.savefig(buf, format='png', bbox_inches='tight', dpi=120, facecolor=fig.get_facecolor())
# /workspaces/Travel-Itinerary-Agent/src/tools/map_visualizer.py:102: UserWarning: Glyph 127747 (\N{NIGHT WITH STARS}) missing from font(s) DejaVu Sans.
# ...

# %%
# Detailed Pakistan City Demo - Islamabad
print("🇵🇰 DETAILED PAKISTAN DEMO - ISLAMABAD")
print("=" * 50)

islamabad_result = mock_agent.plan_trip(
    destination="Islamabad",
    duration=4,
    budget=800,
    style="cultural",
    travelers=2,
    interests=["history", "nature", "food"],
    month="April"
)

print(f"\n✅ Islamabad Trip Planned Successfully!")
print(f"📍 {len(islamabad_result['attractions'])} attractions researched")
print(f"📅 {len(islamabad_result['itinerary'])} day itinerary built")
print(f"💰 ${islamabad_result['budget']['total_budget']} ({islamabad_result['budget']['budget_level']} level)")
print(f"🌤️ {islamabad_result['weather']['temperature']} - {islamabad_result['weather']['weather_conditions']}")
# Out:
# 🇵🇰 DETAILED PAKISTAN DEMO - ISLAMABAD
# ...
# 🚀 Planning 4-day cultural trip to Islamabad...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
#
# ✅ Islamabad Trip Planned Successfully!
# 📍 5 attractions researched
# 📅 4 day itinerary built
# 💰 $800 (Budget level)
# 🌤️ 15-25°C - Pleasant with blooming flowers

# %%
# Display Islamabad Visualizations
from IPython.display import display, HTML, Markdown

print("📊 Generating Islamabad Trip Visualizations...")

# Display itinerary map
display(HTML(f'<h3>🗺️ Islamabad 4-Day Cultural Itinerary</h3><img src="{islamabad_result["map"]}" width="700">'))

# Display budget chart  
display(HTML(f'<h3>💰 Islamabad Trip Budget Breakdown</h3><img src="{islamabad_result["budget_chart"]}" width="800">'))

# Display detailed summary
display(Markdown(f"""
### 🏞️ Islamabad Cultural Trip

**Destination**: {islamabad_result['destination']} - {islamabad_result['researched_destinations']['description']}
**Duration**: {len(islamabad_result['itinerary'])} days  
**Travelers**: 2  
**Budget**: ${islamabad_result['budget']['total_budget']} ({islamabad_result['budget']['budget_level']} level)
**Travel Style**: Cultural  
**Best Season**: {islamabad_result['researched_destinations']['best_season']}
**Weather**: {islamabad_result['weather']['temperature']} - {islamabad_result['weather']['weather_conditions']}

**🏛️ Top Attractions**:
- {islamabad_result['attractions'][0]}
- {islamabad_result['attractions'][1]}
- {islamabad_result['attractions'][2]}

**🎯 Cultural Activities**:
- Visit Faisal Mosque (one of the largest mosques in the world)
- Explore Lok Virsa Museum for cultural heritage
- Hike in Margalla Hills National Park
- Enjoy traditional Pakistani cuisine

**🎒 Packing Recommendations**:
{chr(10).join(f"- {item}" for item in islamabad_result['weather']['packing_recommendations'][:3])}

**💰 Budget Highlights**:
- Accommodation: ${islamabad_result['budget']['budget_breakdown']['accommodation']}
- Food & Dining: ${islamabad_result['budget']['budget_breakdown']['food_dining']}
- Activities: ${islamabad_result['budget']['budget_breakdown']['activities_entertainment']}
- Daily Budget: ${islamabad_result['budget']['budget_per_day']}
"""))
# Out:
# 📊 Generating Islamabad Trip Visualizations...
# <h3>🗺️ Islamabad 4-Day Cultural Itinerary</h3><img src="data:image/png;base64,..." width="700">
# <h3>💰 Islamabad Trip Budget Breakdown</h3><img src="data:image/png;base64,..." width="800">
# ### 🏞️ Islamabad Cultural Trip
#
# **Destination**: Islamabad - Capital city with beautiful mountains and modern architecture
# **Duration**: 4 days
# **Travelers**: 2
# **Budget**: $800 (Budget level)
# **Travel Style**: Cultural
# **Best Season**: Spring (March-May) and Autumn (September-November)
# **Weather**: 15-25°C - Pleasant with blooming flowers
#
# **🏛️ Top Attractions**:
# - Faisal Mosque
# - Daman-e-Koh
# - Pakistan Monument
#
# **🎯 Cultural Activities**:
# - Visit Faisal Mosque (one of the largest mosques in the world)
# - Explore Lok Virsa Museum for cultural heritage
# - Hike in Margalla Hills National Park
# - Enjoy traditional Pakistani cuisine
#
# **🎒 Packing Recommendations**:
# - Light jacket
# - Comfortable shoes
# ...

# %%
# Mountain Adventure Demo - Hunza
print("🏔️ PAKISTAN MOUNTAIN ADVENTURE - HUNZA VALLEY")
print("=" * 55)

hunza_result = mock_agent.plan_trip(
    destination="Hunza",
    duration=5,
    budget=1000,
    style="adventure", 
    travelers=2,
    interests=["mountains", "photography", "culture", "hiking"],
    month="July"
)

print(f"\n✅ Hunza Valley Adventure Planned!")
print(f"📍 {len(hunza_result['attractions'])} mountain attractions")
print(f"📅 {len(hunza_result['itinerary'])} day adventure itinerary")
print(f"💰 ${hunza_result['budget']['total_budget']} ({hunza_result['budget']['budget_level']} level)")
print(f"🌤️ {hunza_result['weather']['temperature']} - Perfect for trekking!")
# Out:
# 🏔️ PAKISTAN MOUNTAIN ADVENTURE - HUNZA VALLEY
# ...
# 🚀 Planning 5-day adventure trip to Hunza...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
#
# ✅ Hunza Valley Adventure Planned!
# 📍 5 mountain attractions
# 📅 5 day adventure itinerary
# 💰 $1000 (Budget level)
# 🌤️ 10-25°C - Perfect for trekking!

# %%
# Display Hunza Visualizations
print("📊 Generating Hunza Valley Adventure Visualizations...")

# Display itinerary map
display(HTML(f'<h3>🏔️ Hunza Valley 5-Day Adventure Itinerary</h3><img src="{hunza_result["map"]}" width="700">'))

# Display budget chart
display(HTML(f'<h3>💰 Hunza Adventure Budget</h3><img src="{hunza_result["budget_chart"]}" width="800">'))

display(Markdown(f"""
### 🏔️ Hunza Valley Adventure

**Destination**: {hunza_result['destination']} - {hunza_result['researched_destinations']['description']}
**Duration**: {len(hunza_result['itinerary'])} days of adventure  
**Travelers**: 2  
**Budget**: ${hunza_result['budget']['total_budget']} ({hunza_result['budget']['budget_level']} level)
**Adventure Style**: Mountain Exploration  
**Best Season**: {hunza_result['researched_destinations']['best_season']}
**Weather**: {hunza_result['weather']['temperature']} - {hunza_result['weather']['weather_conditions']}

**⛰️ Top Mountain Attractions**:
- {hunza_result['attractions'][0]}
- {hunza_result['attractions'][1]}
- {hunza_result['attractions'][2]}

**🚀 Adventure Activities**:
- Trekking in Karakoram mountains
- Photography of stunning landscapes
- Cultural immersion with local communities
- Lake visits and mountain passes

**🎒 Adventure Gear**:
{chr(10).join(f"- {item}" for item in hunza_result['weather']['packing_recommendations'])}

**💰 Adventure Budget**:
- Accommodation: ${hunza_result['budget']['budget_breakdown']['accommodation']}
- Food: ${hunza_result['budget']['budget_breakdown']['food_dining']}
- Adventure Activities: ${hunza_result['budget']['budget_breakdown']['activities_entertainment']}
- Transportation: ${hunza_result['budget']['budget_breakdown']['transportation']}
"""))
# Out:
# 📊 Generating Hunza Valley Adventure Visualizations...
# <h3>🏔️ Hunza Valley 5-Day Adventure Itinerary</h3><img src="data:image/png;base64,..." width="700">
# <h3>💰 Hunza Adventure Budget</h3><img src="data:image/png;base64,..." width="800">
# ### 🏔️ Hunza Valley Adventure
#
# **Destination**: Hunza - Breathtaking mountain valley in the Karakoram range
# **Duration**: 5 days of adventure
# **Travelers**: 2
# **Budget**: $1000 (Budget level)
# **Adventure Style**: Mountain Exploration
# **Best Season**: Summer (May-September)
# **Weather**: 10-25°C - Pleasant with clear skies
#
# **⛰️ Top Mountain Attractions**:
# - Baltit Fort
# - Attabad Lake
# - Passu Cones
#
# **🚀 Adventure Activities**:
# - Trekking in Karakoram mountains
# - Photography of stunning landscapes
# - Cultural immersion with local communities
# - Lake visits and mountain passes
#
# **🎒 Adventure Gear**:
# - Layered clothing
# - Warm jacket
# - Sunglasses
# - Hiking boots
#
# **💰 Adventure Budget**:
# ...

# %%
# Compare All Destinations
print("🌍 COMPARING ALL DESTINATIONS")
print("=" * 40)

all_destinations = [
    {"name": "Paris", "budget": 2000, "style": "cultural"},
    {"name": "Tokyo", "budget": 2500, "style": "mixed"},
    {"name": "Bali", "budget": 1500, "style": "relaxation"},
    {"name": "Islamabad", "budget": 800, "style": "cultural"},
    {"name": "Hunza", "budget": 1000, "style": "adventure"}
]

print("4-Day Trip Cost Comparison:\n")

for dest in all_destinations:
    budget_data = calculate_budget_breakdown(
        dest['name'], 4, dest['budget'], dest['style'], 2
    )
    
    flag = "🇫🇷" if dest['name'] == "Paris" else "🇯🇵" if dest['name'] == "Tokyo" else "🇮🇩" if dest['name'] == "Bali" else "🇵🇰"
    
    print(f"{flag} {dest['name']:12} | 💵 ${budget_data['total_budget']:5} | "
          f"📅 ${budget_data['budget_per_day']:5}/day | "
          f"🏷️ {budget_data['budget_level']:8} | "
          f"🏨 ${budget_data['budget_breakdown']['accommodation']:5}")
# Out:
# 🌍 COMPARING ALL DESTINATIONS
# ...
# 4-Day Trip Cost Comparison:
#
# 🇫🇷 Paris        | 💵 $ 2000 | 📅 $500.0/day | 🏷️ Comfort  | 🏨 $700.0
# 🇯🇵 Tokyo        | 💵 $ 2500 | 📅 $625.0/day | 🏷️ Luxury   | 🏨 $875.0
# 🇮🇩 Bali         | 💵 $ 1500 | 📅 $375.0/day | 🏷️ Budget   | 🏨 $525.0
# 🇵🇰 Islamabad    | 💵 $  800 | 📅 $200.0/day | 🏷️ Budget   | 🏨 $280.0
# 🇵🇰 Hunza        | 💵 $ 1000 | 📅 $250.0/day | 🏷️ Budget   | 🏨 $350.0

# %%
# Quick Test Function
def quick_test(destination, duration, budget, style, travelers=1, interests=None, month=None):
    """Quickly test the agent with different inputs"""
    print(f"🧪 TESTING: {destination} | {duration} days | ${budget} | {style} style")
    print("-" * 60)
    
    result = mock_agent.plan_trip(
        destination=destination,
        duration=duration,
        budget=budget,
        style=style,
        travelers=travelers,
        interests=interests,
        month=month
    )
    
    print(f"\n📊 RESULTS:")
    print(f"📍 Attractions: {len(result['attractions'])} found")
    print(f"📅 Itinerary: {len(result['itinerary'])} days planned")
    print(f"💰 Budget Level: {result['budget']['budget_level']}")
    print(f"🌤️ Weather: {result['weather']['temperature']}")
    print(f"🎒 Packing Tip: {result['weather']['packing_recommendations'][0]}")
    
    return result

# Test different scenarios
print("🚀 QUICK AGENT TESTING")
print("=" * 50)
# Out:
# 🚀 QUICK AGENT TESTING
# ...

# %%
# Test Different Travel Styles for Same Destination
print("🎯 TESTING DIFFERENT TRAVEL STYLES - ISLAMABAD")
print("=" * 55)

styles = ["cultural", "adventure", "relaxation", "budget", "luxury"]

for style in styles:
    print(f"\n🏙️ Islamabad - {style.upper()} Style:")
    result = quick_test("Islamabad", 3, 600, style, 2, ["sightseeing"], "April")
    print(f"   🏨 Accommodation: ${result['budget']['budget_breakdown']['accommodation']}")
    print(f"   🍽️ Food: ${result['budget']['budget_breakdown']['food_dining']}")
# Out:
# 🎯 TESTING DIFFERENT TRAVEL STYLES - ISLAMABAD
# ...
#
# 🏙️ Islamabad - CULTURAL Style:
# 🧪 TESTING: Islamabad | 3 days | $600 | cultural style
# ------------------------------------------------------------
# 🚀 Planning 3-day cultural trip to Islamabad...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
#
# 📊 RESULTS:
# 📍 Attractions: 5 found
# 📅 Itinerary: 3 days planned
# 💰 Budget Level: Budget
# 🌤️ Weather: 15-25°C
# 🎒 Packing Tip: Light jacket
#    🏨 Accommodation: $210.0
#    🍽️ Food: $150.0
#
# 🏙️ Islamabad - ADVENTURE Style:
# 🧪 TESTING: Islamabad | 3 days | $600 | adventure style
# ------------------------------------------------------------
# 🚀 Planning 3-day adventure trip to Islamabad...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
#
# ...

# %%
# Test Different Travel Styles for Same Destination
print("🎯 TESTING DIFFERENT TRAVEL STYLES - ISLAMABAD")
print("=" * 55)

styles = ["cultural", "adventure", "relaxation", "budget", "luxury"]

for style in styles:
    print(f"\n🏙️ Islamabad - {style.upper()} Style:")
    result = quick_test("Islamabad", 3, 600, style, 2, ["sightseeing"], "April")
    print(f"   🏨 Accommodation: ${result['budget']['budget_breakdown']['accommodation']}")
    print(f"   🍽️ Food: ${result['budget']['budget_breakdown']['food_dining']}")
# Out:
# 🎯 TESTING DIFFERENT TRAVEL STYLES - ISLAMABAD
# ...
#
# 🏙️ Islamabad - CULTURAL Style:
# 🧪 TESTING: Islamabad | 3 days | $600 | cultural style
# ------------------------------------------------------------
# 🚀 Planning 3-day cultural trip to Islamabad...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
#
# 📊 RESULTS:
# 📍 Attractions: 5 found
# 📅 Itinerary: 3 days planned
# 💰 Budget Level: Budget
# 🌤️ Weather: 15-25°C
# 🎒 Packing Tip: Light jacket
#    🏨 Accommodation: $210.0
#    🍽️ Food: $150.0
#
# 🏙️ Islamabad - ADVENTURE Style:
# 🧪 TESTING: Islamabad | 3 days | $600 | adventure style
# ------------------------------------------------------------
# 🚀 Planning 3-day adventure trip to Islamabad...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
#
# ...

# %%
# Test Different Budget Levels
print("\n💰 TESTING DIFFERENT BUDGET LEVELS - LAHORE")
print("=" * 50)

budgets = [300, 600, 1000, 2000]  # Budget to Luxury

for budget in budgets:
    print(f"\n💵 Lahore - ${budget} budget:")
    result = quick_test("Lahore", 3, budget, "cultural", 2, ["history", "food"], "November")
    print(f"   📊 Budget Level: {result['budget']['budget_level']}")
    print(f"   📅 Daily: ${result['budget']['budget_per_day']}")
# Out:
# 💰 TESTING DIFFERENT BUDGET LEVELS - LAHORE
# ...
#
# 💵 Lahore - $300 budget:
# 🧪 TESTING: Lahore | 3 days | $300 | cultural style
# ------------------------------------------------------------
# 🚀 Planning 3-day cultural trip to Lahore...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
#
# 📊 RESULTS:
# 📍 Attractions: 5 found
# 📅 Itinerary: 3 days planned
# 💰 Budget Level: Budget
# 🌤️ Weather: 5-20°C
# 🎒 Packing Tip: Warm layers
#    📊 Budget Level: Budget
#    📅 Daily: $100.0
#
# 💵 Lahore - $600 budget:
# 🧪 TESTING: Lahore | 3 days | $600 | cultural style
# ------------------------------------------------------------
# 🚀 Planning 3-day cultural trip to Lahore...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
#
# 📊 RESULTS:
# ...

# %%
# Test Different Seasons
print("\n🌤️ TESTING DIFFERENT SEASONS - HUNZA")
print("=" * 45)

seasons = [
    ("January", "Winter"),
    ("April", "Spring"), 
    ("July", "Summer"),
    ("October", "Autumn")
]

for month, season in seasons:
    print(f"\n❄️ Hunza - {season} ({month}):")
    result = quick_test("Hunza", 4, 800, "adventure", 2, ["mountains", "photography"], month)
    print(f"   🌡️ Temperature: {result['weather']['temperature']}")
    print(f"   ☁️ Conditions: {result['weather']['weather_conditions']}")
# Out:
# 🌤️ TESTING DIFFERENT SEASONS - HUNZA
# ...
#
# ❄️ Hunza - Winter (January):
# 🧪 TESTING: Hunza | 4 days | $800 | adventure style
# ------------------------------------------------------------
# 🚀 Planning 4-day adventure trip to Hunza...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
#
# 📊 RESULTS:
# 📍 Attractions: 5 found
# 📅 Itinerary: 4 days planned
# 💰 Budget Level: Budget
# 🌤️ Weather: -10 to 10°C
# 🎒 Packing Tip: Heavy winter coat
#    🌡️ Temperature: -10 to 10°C
#    ☁️ Conditions: Cold with snow
#
# ❄️ Hunza - Spring (April):
# 🧪 TESTING: Hunza | 4 days | $800 | adventure style
# ------------------------------------------------------------
# 🚀 Planning 4-day adventure trip to Hunza...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
#
# ...

# %%
# Test Different Group Sizes
print("\n👥 TESTING DIFFERENT GROUP SIZES - KARACHI")
print("=" * 50)

group_sizes = [1, 2, 4, 6]

for travelers in group_sizes:
    print(f"\n👤 Karachi - {travelers} traveler(s):")
    result = quick_test("Karachi", 3, 400, "mixed", travelers, ["beach", "food"], "January")
    print(f"   💰 Total: ${result['budget']['total_budget']}")
    print(f"   👤 Per Person: ${result['budget']['budget_per_person']}")
# Out:
# 👥 TESTING DIFFERENT GROUP SIZES - KARACHI
# ...
#
# 👤 Karachi - 1 traveler(s):
# 🧪 TESTING: Karachi | 3 days | $400 | mixed style
# ------------------------------------------------------------
# 🚀 Planning 3-day mixed trip to Karachi...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
#
# 📊 RESULTS:
# 📍 Attractions: 5 found
# 📅 Itinerary: 3 days planned
# 💰 Budget Level: Budget
# 🌤️ Weather: 15-25°C
# 🎒 Packing Tip: Light jacket
#    💰 Total: $400
#    👤 Per Person: $400.0
#
# 👤 Karachi - 2 traveler(s):
# 🧪 TESTING: Karachi | 3 days | $400 | mixed style
# ------------------------------------------------------------
# 🚀 Planning 3-day mixed trip to Karachi...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
#
# 📊 RESULTS:
# 📍 Attractions: 5 found
# ...

# %%
# Compare Different City Types
print("\n🏙️ COMPARING DIFFERENT CITY TYPES")
print("=" * 45)

city_types = [
    ("Islamabad", "capital", "cultural"),
    ("Karachi", "coastal", "mixed"),
    ("Lahore", "historical", "cultural"),
    ("Hunza", "mountain", "adventure"),
    ("Swat", "valley", "adventure")
]

for city, city_type, style in city_types:
    print(f"\n📍 {city} ({city_type}):")
    result = quick_test(city, 3, 600, style, 2, ["sightseeing"], "May")
    print(f"   🏷️ Cost Level: {result['researched_destinations']['cost_level']}")
    print(f"   🌄 Best Season: {result['researched_destinations']['best_season']}")
# Out:
# 🏙️ COMPARING DIFFERENT CITY TYPES
# ...
#
# 📍 Islamabad (capital):
# 🧪 TESTING: Islamabad | 3 days | $600 | cultural style
# ------------------------------------------------------------
# 🚀 Planning 3-day cultural trip to Islamabad...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
#
# 📊 RESULTS:
# 📍 Attractions: 5 found
# 📅 Itinerary: 3 days planned
# 💰 Budget Level: Budget
# 🌤️ Weather: 15-25°C
# 🎒 Packing Tip: Light jacket
#    🏷️ Cost Level: Medium
#    🌄 Best Season: Spring (March-May) and Autumn (September-November)
#
# 📍 Karachi (coastal):
# 🧪 TESTING: Karachi | 3 days | $600 | mixed style
# ------------------------------------------------------------
# 🚀 Planning 3-day mixed trip to Karachi...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# ...

# %%
# Interactive Testing
def interactive_test():
    """Interactively test the agent"""
    print("🎮 INTERACTIVE AGENT TESTING")
    print("=" * 40)
    
    destination = input("Enter destination: ") or "Islamabad"
    duration = int(input("Enter duration (days): ") or "3")
    budget = float(input("Enter budget ($): ") or "500")
    style = input("Enter travel style: ") or "cultural"
    travelers = int(input("Enter number of travelers: ") or "2")
    month = input("Enter travel month: ") or "April"
    
    interests_input = input("Enter interests (comma separated): ") or "sightseeing,food"
    interests = [interest.strip() for interest in interests_input.split(",")]
    
    print(f"\n🧪 Testing: {destination} | {duration} days | ${budget} | {style} | {travelers} people")
    print("-" * 60)
    
    result = mock_agent.plan_trip(
        destination=destination,
        duration=duration,
        budget=budget,
        style=style,
        travelers=travelers,
        interests=interests,
        month=month
    )
    
    # Display results
    from IPython.display import display, HTML, Markdown
    
    display(HTML(f'<h3>🗺️ {destination} Itinerary</h3><img src="{result["map"]}" width="600">'))
    display(HTML(f'<h3>💰 Budget Breakdown</h3><img src="{result["budget_chart"]}" width="700">'))
    
    display(Markdown(f"""
    ### 📊 Trip Summary
    
    **Destination**: {result['destination']}
    **Duration**: {len(result['itinerary'])} days
    **Budget**: ${result['budget']['total_budget']} ({result['budget']['budget_level']})
    **Travelers**: {result['budget']['traveler_count']}
    **Weather**: {result['weather']['temperature']}
    
    **Top Attractions**:
    - {result['attractions'][0]}
    - {result['attractions'][1]}
    - {result['attractions'][2]}
    """))
    
    return result

# Uncomment the line below to run interactive testing
interactive_test()
# Out:
# 🎮 INTERACTIVE AGENT TESTING
# ...
#
# 🧪 Testing: islamabad | 3 days | $400.0 | any | 3 people
# ------------------------------------------------------------
# 🚀 Planning 3-day any trip to islamabad...
# 🔍 Researching destination...
# 📅 Building itinerary...
# 💰 Calculating budget...
# 🌤️ Checking weather...
# 🗺️ Generating visualizations...
# 📝 Creating final report...
# <h3>🗺️ islamabad Itinerary</h3><img src="data:image/png;base64,..." width="600">
# <h3>💰 Budget Breakdown</h3><img src="data:image/png;base64,..." width="700">
#     ### 📊 Trip Summary
#
#     **Destination**: islamabad
#     **Duration**: 3 days
#     **Budget**: $400.0 (Budget)
#     **Travelers**: 3
#     **Weather**: 5-18°C
#
#     **Top Attractions**:
#     - Faisal Mosque
#     - Daman-e-Koh
#     - Pakistan Monument
# {'destination': 'islamabad',
#  'itinerary': [{'day': 1,
#    'morning': 'Sightseeing and main attractions at Faisal Mosque',
#    'afternoon': 'Local experiences and exploration in islamabad',
# ...
