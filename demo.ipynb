# %%
# Travel Itinerary Agent - Demo Notebook
# Testing Destination Research and Itinerary Builder

import sys
import os

# Add the src directory to Python path
sys.path.insert(0, os.path.abspath('src'))

from tools.destination_research import research_destination
from tools.itinerary_builder import build_daily_itinerary

print("🚀 Travel Agent Tools Demo")
print("=" * 50)
# Out:
# 🚀 Travel Agent Tools Demo
# ...

# %%
# Test Destination Research
print("1. Testing Destination Research Tool")
print("-" * 40)

# Test Paris
paris_info = research_destination("Paris", ["museums", "food"])
print("🇫🇷 Paris Research:")
print(f"   Description: {paris_info['description']}")
print(f"   Best Season: {paris_info['best_season']}")
print(f"   Cost Level: {paris_info['cost_level']}")
print(f"   Top Attractions: {', '.join(paris_info['attractions'][:3])}")
print(f"   Activities: {', '.join(paris_info['activities'][:3])}")

print("\n")

# Test Tokyo
tokyo_info = research_destination("Tokyo", ["temples", "shopping"])
print("🗼 Tokyo Research:")
print(f"   Description: {tokyo_info['description']}")
print(f"   Best Season: {tokyo_info['best_season']}")
print(f"   Cost Level: {tokyo_info['cost_level']}")
print(f"   Top Attractions: {', '.join(tokyo_info['attractions'][:3])}")
# Out:
# 1. Testing Destination Research Tool
# ----------------------------------------
# 🇫🇷 Paris Research:
#    Description: City of Lights with rich history and culture
#    Best Season: Spring (March-May)
#    Cost Level: Medium
#    Top Attractions: Eiffel Tower, Louvre Museum, Notre-Dame
#    Activities: Museum tours, River cruise, Food tasting
#
#
# 🗼 Tokyo Research:
#    Description: Blend of traditional and ultra-modern experiences
#    Best Season: Autumn (September-November)
#    Cost Level: High
#    Top Attractions: Sensoji Temple, Tokyo Skytree, Shibuya Crossing

# %%
# Test Itinerary Builder with Paris
print("\n2. Testing Itinerary Builder - Paris Cultural Trip")
print("-" * 50)

paris_itinerary = build_daily_itinerary(
    destination="Paris",
    duration=3,
    travel_style="cultural",
    attractions=paris_info['attractions'][:4]
)

print(f"📅 Created {len(paris_itinerary)}-Day Paris Cultural Itinerary:\n")

for day in paris_itinerary:
    print(f"Day {day['day']}:")
    print(f"  🌅 Morning: {day['morning']}")
    print(f"  🌇 Afternoon: {day['afternoon']}")
    print(f"  🌃 Evening: {day['evening']}")
    print(f"  🍽️ Meals: {day['meals']}")
    print(f"  🏨 Accommodation: {day['accommodation_type']}")
    print()
# Out:
# 2. Testing Itinerary Builder - Paris Cultural Trip
# --------------------------------------------------
# 📅 Created 3-Day Paris Cultural Itinerary:
#
# Day 1:
#   🌅 Morning: Museum and historical site visits at Eiffel Tower
#   🌇 Afternoon: Cultural workshops and local experiences in Paris
#   🌃 Evening: Traditional performances and dining with local cuisine
#   🍽️ Meals: Breakfast at accommodation, Lunch at local restaurant, Dinner at recommended spot
#   🏨 Accommodation: Hotel
#
# Day 2:
#   🌅 Morning: Museum and historical site visits at Louvre Museum
#   🌇 Afternoon: Cultural workshops and local experiences in Paris
#   🌃 Evening: Traditional performances and dining with local cuisine
#   🍽️ Meals: Breakfast at accommodation, Lunch at local restaurant, Dinner at recommended spot
#   🏨 Accommodation: Hotel
#
# Day 3:
#   🌅 Morning: Museum and historical site visits at Notre-Dame
#   🌇 Afternoon: Cultural workshops and local experiences in Paris
# ...

# %%
# Test Itinerary Builder with Paris
print("\n2. Testing Itinerary Builder - Paris Cultural Trip")
print("-" * 50)

paris_itinerary = build_daily_itinerary(
    destination="Paris",
    duration=3,
    travel_style="cultural",
    attractions=paris_info['attractions'][:4]
)

print(f"📅 Created {len(paris_itinerary)}-Day Paris Cultural Itinerary:\n")

for day in paris_itinerary:
    print(f"Day {day['day']}:")
    print(f"  🌅 Morning: {day['morning']}")
    print(f"  🌇 Afternoon: {day['afternoon']}")
    print(f"  🌃 Evening: {day['evening']}")
    print(f"  🍽️ Meals: {day['meals']}")
    print(f"  🏨 Accommodation: {day['accommodation_type']}")
    print()
# Out:
# 2. Testing Itinerary Builder - Paris Cultural Trip
# --------------------------------------------------
# 📅 Created 3-Day Paris Cultural Itinerary:
#
# Day 1:
#   🌅 Morning: Museum and historical site visits at Eiffel Tower
#   🌇 Afternoon: Cultural workshops and local experiences in Paris
#   🌃 Evening: Traditional performances and dining with local cuisine
#   🍽️ Meals: Breakfast at accommodation, Lunch at local restaurant, Dinner at recommended spot
#   🏨 Accommodation: Hotel
#
# Day 2:
#   🌅 Morning: Museum and historical site visits at Louvre Museum
#   🌇 Afternoon: Cultural workshops and local experiences in Paris
#   🌃 Evening: Traditional performances and dining with local cuisine
#   🍽️ Meals: Breakfast at accommodation, Lunch at local restaurant, Dinner at recommended spot
#   🏨 Accommodation: Hotel
#
# Day 3:
#   🌅 Morning: Museum and historical site visits at Notre-Dame
#   🌇 Afternoon: Cultural workshops and local experiences in Paris
# ...

# %%
# Step 8: Test Budget Calculator Tool
print("💰 STEP 8: Testing Budget Calculator")
print("=" * 50)

from tools.budget_calculator import calculate_budget_breakdown, generate_budget_chart

# Test different budget scenarios
test_cases = [
    {"destination": "Paris", "duration": 5, "budget": 2000, "style": "cultural", "travelers": 2},
    {"destination": "Tokyo", "duration": 7, "budget": 3000, "style": "comfort", "travelers": 1},
    {"destination": "Bali", "duration": 10, "budget": 1500, "style": "budget", "travelers": 2}
]

for i, case in enumerate(test_cases, 1):
    print(f"\n{i}. {case['destination']} - {case['duration']} days - ${case['budget']}:")
    
    budget_result = calculate_budget_breakdown(
        destination=case['destination'],
        duration=case['duration'],
        total_budget=case['budget'],
        travel_style=case['style'],
        traveler_count=case['travelers']
    )
    
    print(f"   🏷️ Budget Level: {budget_result['budget_level']}")
    print(f"   💰 Total Budget: ${budget_result['total_budget']}")
    print(f"   📅 Budget per day: ${budget_result['budget_per_day']}")
    print(f"   👤 Budget per person: ${budget_result['budget_per_person']}")
    print(f"   🏨 Accommodation: ${budget_result['budget_breakdown']['accommodation']}")
    print(f"   🍽️ Food & Dining: ${budget_result['budget_breakdown']['food_dining']}")
    print(f"   🎯 Activities: ${budget_result['budget_breakdown']['activities_entertainment']}")
# Out:
# 💰 STEP 8: Testing Budget Calculator
# ...
#
# 1. Paris - 5 days - $2000:
#    🏷️ Budget Level: Comfort
#    💰 Total Budget: $2000
#    📅 Budget per day: $400.0
#    👤 Budget per person: $1000.0
#    🏨 Accommodation: $700.0
#    🍽️ Food & Dining: $500.0
#    🎯 Activities: $400.0
#
# 2. Tokyo - 7 days - $3000:
#    🏷️ Budget Level: Luxury
#    💰 Total Budget: $3000
#    📅 Budget per day: $428.57
#    👤 Budget per person: $3000.0
#    🏨 Accommodation: $1050.0
#    🍽️ Food & Dining: $750.0
#    🎯 Activities: $600.0
#
# 3. Bali - 10 days - $1500:
#    🏷️ Budget Level: Budget
#    💰 Total Budget: $1500
#    📅 Budget per day: $150.0
#    👤 Budget per person: $750.0
#    🏨 Accommodation: $525.0
#    🍽️ Food & Dining: $375.0
#    🎯 Activities: $300.0

# %%
# Test Budget Visualization
print("\n📊 Testing Budget Visualization")
print("-" * 40)

# Use the Paris case for visualization
paris_budget = calculate_budget_breakdown(
    destination="Paris",
    duration=5,
    total_budget=2000,
    travel_style="cultural",
    traveler_count=2
)

# Generate chart
chart_image = generate_budget_chart(paris_budget['budget_breakdown'])

# Display the chart in notebook
from IPython.display import display, HTML
display(HTML(f'<h3>Paris Trip Budget Breakdown</h3><img src="{chart_image}" width="500">'))

print("✅ Budget chart generated successfully!")
print(f"📈 Chart shows allocation of ${paris_budget['total_budget']} budget")
# Out:
# 📊 Testing Budget Visualization
# ----------------------------------------
# <h3>Paris Trip Budget Breakdown</h3><img src="data:image/png;base64,..." width="500">
# ✅ Budget chart generated successfully!
# 📈 Chart shows allocation of $2000 budget

# %%
# Detailed Budget Analysis
print("\n🔍 Detailed Budget Analysis - Paris Trip")
print("-" * 45)

print(f"Trip: {paris_budget['trip_duration']} days in Paris for {paris_budget['traveler_count']} travelers")
print(f"Total Budget: ${paris_budget['total_budget']}")
print(f"Budget Level: {paris_budget['budget_level']}")
print("\n📋 Category Breakdown:")
print("-" * 25)

for category, amount in paris_budget['budget_breakdown'].items():
    daily_amount = paris_budget['daily_breakdown'][category]
    category_name = category.replace('_', ' ').title()
    print(f"   {category_name}: ${amount} total (${daily_amount}/day)")

print(f"\n💡 Tips:")
print(f"   • Daily budget: ${paris_budget['budget_per_day']}")
print(f"   • Per person: ${paris_budget['budget_per_person']}")
print(f"   • Consider saving 3% (${paris_budget['budget_breakdown']['emergency_misc']}) for emergencies")
# Out:
# 🔍 Detailed Budget Analysis - Paris Trip
# ---------------------------------------------
# Trip: 5 days in Paris for 2 travelers
# Total Budget: $2000
# Budget Level: Comfort
#
# 📋 Category Breakdown:
# -------------------------
#    Accommodation: $700.0 total ($140.0/day)
#    Food Dining: $500.0 total ($100.0/day)
#    Activities Entertainment: $400.0 total ($80.0/day)
#    Transportation: $240.0 total ($48.0/day)
#    Shopping Souvenirs: $100.0 total ($20.0/day)
#    Emergency Misc: $60.0 total ($12.0/day)
#
# 💡 Tips:
#    • Daily budget: $400.0
#    • Per person: $1000.0
#    • Consider saving 3% ($60.0) for emergencies

# %%
# Step 9: Testing Weather Checker Tool
print("🌤️ STEP 9: Testing Weather Checker Tool")
print("=" * 50)

from tools.weather_checker import get_seasonal_weather

# Test weather for different destinations and seasons
weather_tests = [
    {"destination": "Paris", "month": "May"},
    {"destination": "Tokyo", "month": "August"}, 
    {"destination": "Bali", "month": "July"},
    {"destination": "Paris", "month": "December"},
    {"destination": "Unknown City", "month": "June"}
]

print("🌍 Weather Forecast for Various Destinations:")
print("-" * 50)

for i, test in enumerate(weather_tests, 1):
    print(f"\n{i}. {test['destination']} in {test['month']}:")
    
    weather_info = get_seasonal_weather(
        destination=test['destination'],
        travel_month=test['month']
    )
    
    print(f"   🌡️ Temperature: {weather_info['temperature']}")
    print(f"   ☁️ Conditions: {weather_info['weather_conditions']}")
    print(f"   📦 Packing: {', '.join(weather_info['packing_recommendations'][:2])}")
    print(f"   🌧️ Rainfall: {weather_info['average_rainfall']}")
    print(f"   ☀️ Sunlight: {weather_info['daily_sunlight']}")
    
    if weather_info['special_notes']:
        print(f"   💡 Note: {weather_info['special_notes']}")
# Out:
# 🌤️ STEP 9: Testing Weather Checker Tool
# ...
# 🌍 Weather Forecast for Various Destinations:
# --------------------------------------------------
#
# 1. Paris in May:
#    🌡️ Temperature: 10-18°C
#    ☁️ Conditions: Mild with occasional rain
#    📦 Packing: Light jacket, Umbrella
#    🌧️ Rainfall: Moderate
#    ☀️ Sunlight: 12-14 hours
#
# 2. Tokyo in August:
#    🌡️ Temperature: 22-30°C
#    ☁️ Conditions: Hot and humid
#    📦 Packing: Light breathable clothing, Hat
#    🌧️ Rainfall: High
#    ☀️ Sunlight: 13-15 hours
#
# 3. Bali in July:
#    🌡️ Temperature: 26-32°C
#    ☁️ Conditions: Warm and sunny
#    📦 Packing: Light clothing, Swimwear
#    🌧️ Rainfall: Low
#    ☀️ Sunlight: 12 hours
#    💡 Note: Dry Season (April-September)
#
# 4. Paris in December:
#    🌡️ Temperature: 2-8°C
#    ☁️ Conditions: Cold with possible snow
#    📦 Packing: Warm coat, Scarf
#    🌧️ Rainfall: Low to Moderate
#    ☀️ Sunlight: 8-9 hours
#
# 5. Unknown City in June:
#    🌡️ Temperature: 15-25°C
# ...

# %%
# Detailed Weather Analysis for Paris Trip
print("\n🔍 Detailed Weather Analysis - Paris Spring Trip")
print("-" * 55)

paris_weather = get_seasonal_weather("Paris", "May")

print(f"Destination: {paris_weather['destination']}")
print(f"Travel Month: {paris_weather['travel_month']}")
print(f"Season: {paris_weather['season'].title()}")
print(f"Temperature Range: {paris_weather['temperature']}")
print(f"Weather Conditions: {paris_weather['weather_conditions']}")
print(f"Average Rainfall: {paris_weather['average_rainfall']}")
print(f"Daily Sunlight: {paris_weather['daily_sunlight']}")

print(f"\n🎒 Packing Recommendations:")
for i, item in enumerate(paris_weather['packing_recommendations'], 1):
    print(f"   {i}. {item}")

if paris_weather['special_notes']:
    print(f"\n💡 Travel Tip: {paris_weather['special_notes']}")
# Out:
# 🔍 Detailed Weather Analysis - Paris Spring Trip
# -------------------------------------------------------
# Destination: Paris
# Travel Month: May
# Season: Spring
# Temperature Range: 10-18°C
# Weather Conditions: Mild with occasional rain
# Average Rainfall: Moderate
# Daily Sunlight: 12-14 hours
#
# 🎒 Packing Recommendations:
#    1. Light jacket
#    2. Umbrella
#    3. Layered clothing

# %%
# Detailed Weather Analysis for Paris Trip
print("\n🔍 Detailed Weather Analysis - Paris Spring Trip")
print("-" * 55)

paris_weather = get_seasonal_weather("Paris", "May")

print(f"Destination: {paris_weather['destination']}")
print(f"Travel Month: {paris_weather['travel_month']}")
print(f"Season: {paris_weather['season'].title()}")
print(f"Temperature Range: {paris_weather['temperature']}")
print(f"Weather Conditions: {paris_weather['weather_conditions']}")
print(f"Average Rainfall: {paris_weather['average_rainfall']}")
print(f"Daily Sunlight: {paris_weather['daily_sunlight']}")

print(f"\n🎒 Packing Recommendations:")
for i, item in enumerate(paris_weather['packing_recommendations'], 1):
    print(f"   {i}. {item}")

if paris_weather['special_notes']:
    print(f"\n💡 Travel Tip: {paris_weather['special_notes']}")
# Out:
# 🔍 Detailed Weather Analysis - Paris Spring Trip
# -------------------------------------------------------
# Destination: Paris
# Travel Month: May
# Season: Spring
# Temperature Range: 10-18°C
# Weather Conditions: Mild with occasional rain
# Average Rainfall: Moderate
# Daily Sunlight: 12-14 hours
#
# 🎒 Packing Recommendations:
#    1. Light jacket
#    2. Umbrella
#    3. Layered clothing

# %%
# Bali Special Case (Tropical Climate)
print("\n🏝️ Bali Tropical Climate Analysis")
print("-" * 40)

bali_dry = get_seasonal_weather("Bali", "July")
bali_wet = get_seasonal_weather("Bali", "January")

print("Dry Season (July):")
print(f"  🌡️ {bali_dry['temperature']} - {bali_dry['weather_conditions']}")
print(f"  🌧️ Rainfall: {bali_dry['average_rainfall']}")
print(f"  💡 {bali_dry['special_notes']}")

print("\nWet Season (January):")
print(f"  🌡️ {bali_wet['temperature']} - {bali_wet['weather_conditions']}")
print(f"  🌧️ Rainfall: {bali_wet['average_rainfall']}")
print(f"  💡 {bali_wet['special_notes']}")

print(f"\n🎒 Dry Season Packing: {', '.join(bali_dry['packing_recommendations'][:2])}")
print(f"🎒 Wet Season Packing: {', '.join(bali_wet['packing_recommendations'][:2])}")
# Out:
# 🏝️ Bali Tropical Climate Analysis
# ----------------------------------------
# Dry Season (July):
#   🌡️ 26-32°C - Warm and sunny
#   🌧️ Rainfall: Low
#   💡 Dry Season (April-September)
#
# Wet Season (January):
#   🌡️ 24-30°C - Warm with heavy rainfall
#   🌧️ Rainfall: High
#   💡 Wet Season (October-March)
#
# 🎒 Dry Season Packing: Light clothing, Swimwear
# 🎒 Wet Season Packing: Light rain jacket, Quick-dry clothing

# %%
# Step 10: Testing Map Visualizer Tool
print("🗺️ STEP 10: Testing Map Visualizer Tool")
print("=" * 50)

from tools.map_visualizer import generate_itinerary_map, generate_budget_vs_duration_chart

print("🎯 Generating visualizations for our Paris trip...")
# Out:
# 🗺️ STEP 10: Testing Map Visualizer Tool
# ...
# 🎯 Generating visualizations for our Paris trip...

# %%
# Generate Itinerary Map for Paris
print("1. Generating Itinerary Map...")

# Get Paris data first
from tools.destination_research import research_destination
from tools.itinerary_builder import build_daily_itinerary

paris_info = research_destination("Paris", ["museums"])
paris_itinerary = build_daily_itinerary(
    destination="Paris", 
    duration=4, 
    travel_style="cultural",
    attractions=paris_info['attractions'][:5]
)

# Generate map
itinerary_map = generate_itinerary_map(
    destination="Paris",
    itinerary=paris_itinerary,
    attractions=paris_info['attractions'][:4]
)

# Display the map
from IPython.display import display, HTML
display(HTML(f'<h3>🗺️ Paris 4-Day Itinerary Map</h3><img src="{itinerary_map}" width="700">'))

print("✅ Itinerary map generated successfully!")
print(f"📋 Shows {len(paris_itinerary)} days with {len(paris_info['attractions'][:4])} key attractions")
# Out:
# 1. Generating Itinerary Map...
# /workspaces/Travel-Itinerary-Agent/src/tools/map_visualizer.py:102: UserWarning: Glyph 127749 (\N{SUNRISE}) missing from font(s) DejaVu Sans.
#   plt.savefig(buf, format='png', bbox_inches='tight', dpi=120, facecolor=fig.get_facecolor())
# /workspaces/Travel-Itinerary-Agent/src/tools/map_visualizer.py:102: UserWarning: Glyph 127751 (\N{SUNSET OVER BUILDINGS}) missing from font(s) DejaVu Sans.
#   plt.savefig(buf, format='png', bbox_inches='tight', dpi=120, facecolor=fig.get_facecolor())
# /workspaces/Travel-Itinerary-Agent/src/tools/map_visualizer.py:102: UserWarning: Glyph 127747 (\N{NIGHT WITH STARS}) missing from font(s) DejaVu Sans.
#   plt.savefig(buf, format='png', bbox_inches='tight', dpi=120, facecolor=fig.get_facecolor())
# /workspaces/Travel-Itinerary-Agent/src/tools/map_visualizer.py:102: UserWarning: Glyph 127963 (\N{CLASSICAL BUILDING}) missing from font(s) DejaVu Sans.
# ...

# %%
# Complete Travel Package Visualization
print("\n4. Complete Travel Package Summary")
print("-" * 45)

# Get all data for Paris
paris_weather = get_seasonal_weather("Paris", "May")

print(f"📍 DESTINATION: {paris_info['description']}")
print(f"📅 DURATION: {len(paris_itinerary)} days")
print(f"💰 BUDGET: ${paris_budget['total_budget']} ({paris_budget['budget_level']} level)")
print(f"🌤️ WEATHER: {paris_weather['temperature']} - {paris_weather['weather_conditions']}")
print(f"🎯 TRAVEL STYLE: Cultural")

print(f"\n🏛️ TOP ATTRACTIONS:")
for i, attraction in enumerate(paris_info['attractions'][:4], 1):
    print(f"   {i}. {attraction}")

print(f"\n🎒 PACKING ESSENTIALS:")
for i, item in enumerate(paris_weather['packing_recommendations'][:3], 1):
    print(f"   {i}. {item}")

print(f"\n📊 BUDGET HIGHLIGHTS:")
print(f"   • Accommodation: ${paris_budget['budget_breakdown']['accommodation']}")
print(f"   • Activities: ${paris_budget['budget_breakdown']['activities_entertainment']}")
print(f"   • Food: ${paris_budget['budget_breakdown']['food_dining']}")
print(f"   • Daily Budget: ${paris_budget['budget_per_day']}")

print(f"\n✅ All tools integrated successfully!")
# Out:
# 4. Complete Travel Package Summary
# ---------------------------------------------
# 📍 DESTINATION: City of Lights with rich history and culture
# 📅 DURATION: 4 days
# 💰 BUDGET: $2000 (Comfort level)
# 🌤️ WEATHER: 10-18°C - Mild with occasional rain
# 🎯 TRAVEL STYLE: Cultural
#
# 🏛️ TOP ATTRACTIONS:
#    1. Eiffel Tower
#    2. Louvre Museum
#    3. Notre-Dame
#    4. Montmartre
#
# 🎒 PACKING ESSENTIALS:
#    1. Light jacket
#    2. Umbrella
#    3. Layered clothing
#
# 📊 BUDGET HIGHLIGHTS:
#    • Accommodation: $700.0
#    • Activities: $400.0
#    • Food: $500.0
#    • Daily Budget: $400.0
#
# ✅ All tools integrated successfully!

# %%
# Step 11: Testing Complete LangGraph Agent
print("🤖 STEP 11: Testing Complete LangGraph Agent")
print("=" * 60)

from src.agent import TravelPlannerAgent

# Initialize the agent
print("Initializing Travel Planner Agent...")
agent = TravelPlannerAgent()
print("✅ Agent initialized successfully!")
# Out:
# 🤖 STEP 11: Testing Complete LangGraph Agent
# ...
# Initializing Travel Planner Agent...
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[19], line 9
#       7 # Initialize the agent
#       8 print("Initializing Travel Planner Agent...")
# ----> 9 agent = TravelPlannerAgent()
#      10 print("✅ Agent initialized successfully!")
#
# File /workspaces/Travel-Itinerary-Agent/src/agent.py:17, in TravelPlannerAgent.__init__(self, model)
#      16 def __init__(self, model: str = "gpt-3.5-turbo"):
# ---> 17     self.llm = ChatOpenAI(model=model, temperature=0.7)
#      18     self.setup_tools()
#      19     self.build_graph()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/load/serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
# ...
